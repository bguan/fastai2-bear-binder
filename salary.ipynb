# %%
from fastai2.learner import *
from fastai2.tabular.learner import *
from fastai2.tabular.model import *
from fastai2.tabular.data import *

import pandas as pd

# %%
learn_inf = load_learner('adult-salary-model.pkl')

# %%
learn_inf.predict??
# Out:
# Signature: learn_inf.predict(row)
# Docstring: Return the prediction on `item`, fully decoded, loss function decoded and probabilities
# Source:
#     def predict(self, row):
#         tst_to = self.dls.valid_ds.new(pd.DataFrame(row).T)
#         tst_to.process()
#         tst_to.conts = tst_to.conts.astype(np.float32)
#         dl = self.dls.valid.new(tst_to)
#         inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#         i = getattr(self.dls, 'n_inp', -1)
#         b = (*tuplify(inp),*tuplify(dec_preds))
#         full_dec = self.dls.decode((*tuplify(inp),*tuplify(dec_preds)))
#         return full_dec,dec_preds[0],preds[0]
# File:      ~/projects/fastai2/fastai2/tabular/learner.py
# Type:      method

# %%
someguy = {
    'workclass': 'Self-emp-not-inc', 
    'education': 'Bachelors',  
    'marital-status': 'Married-civ-spouse', 
    'occupation': 'Exec-managerial',  
    'relationship': 'Husband', 
    'race': 'Asian-Pac-Islander',
    'age': 52.0, 
    'education-num': 17.0,
    'fnlwgt': 1.0,
}
input = pd.DataFrame.from_dict(someguy, 'index')

# %%
learn_inf.dls.procs.setup(items=input)
# Out:
#                                  0
# workclass         Self-emp-not-inc
# education                Bachelors
# marital-status  Married-civ-spouse
# occupation         Exec-managerial
# relationship               Husband
# race            Asian-Pac-Islander
# age                             52
# education-num                   17
# fnlwgt                           1

# %%
learn_inf.predict(input)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/projects/fastai2/fastai2/learner.py in _do_epoch_validate(self, ds_idx, dl)
#     182             self.dl = dl;                                    self('begin_validate')
# --> 183             with torch.no_grad(): self.all_batches()
#     184         except CancelValidException:                         self('after_cancel_validate')
#
# ~/projects/fastai2/fastai2/learner.py in all_batches(self)
#     152         self.n_iter = len(self.dl)
# --> 153         for o in enumerate(self.dl): self.one_batch(*o)
#     154
#
# ~/projects/fastai2/fastai2/data/load.py in __iter__(self)
#      99             if self.device is not None: b = to_device(b, self.device)
# --> 100             yield self.after_batch(b)
#     101         self.after_iter()
#
# ~/projects/fastcore/fastcore/transform.py in __call__(self, o)
#     186
# ...

# %%
profile_form = widgets.???
btn_run = widgets.Button(description='Predict Salary')

out_pl = widgets.Output()
lbl_pred = widgets.Label()

def on_click_predict(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_predict)

VBox([widgets.Label('Enter A Profile!'), 
      profile_form, btn_run, out_pl, lbl_pred])
